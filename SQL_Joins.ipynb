# %% [markdown]
# ANS 1:
# ![Screenshot 2026-09-10 230613.png](data:image/png;base64,...)

# %% [markdown]
# ANS 2:
# ![Screenshot 2026-09-10 231429.png](data:image/png;base64,...)

# %% [markdown]
# ANS 3:
# ![Screenshot 2026-09-10 232821.png](data:image/png;base64,...)

# %% [markdown]
# ANS 4:
# ![Screenshot 2026-09-10 233746.png](data:image/png;base64,...)

# %% [markdown]
# ANS 5: ![Screenshot 2026-09-10 233948.png](data:image/png;base64,...)

# %% [markdown]
# ANS 6: ![Screenshot 2026-09-10 234206.png](data:image/png;base64,...)

# %% [markdown]
# ANS 7:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ANS 8:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ANS 9:
# ![image.png](data:image/png;base64,...)
